# %% [markdown]
# # Optimize distance : forecasting of Lorenz data as a function of loss function type (RMSE vs. CRPS)
#
# This notebook accompanies the following publication:
# Paul Platzer, Arthur Avenas, Bertrand Chapron, Lucas Drumetz, Alexis Mouche, Léo Vinour. Distance Learning for Analog Methods. 2024. [⟨hal-04841334⟩](https://hal.science/hal-04841334)
#
# It is used to run optimization algorithms for numerical experiments with Lorenz system data. In particular, we investigate the dependency of the optimal distance with the type of loss function (i.e. CRPS or RMSE).

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from tqdm.notebook import tqdm
from sklearn.neighbors import NearestNeighbors
import sys
sys.path.append('../../functions/.')
from analogs import apply_transform, find_analogues, compute_weights, compute_diffs, compute_mae_mad, compute_error
from distance_learning import compute_gradient_MSE, compute_gradient_CRPS, compute_regularization, learn_distance

# %%
data_folder = '../../data/lorenz/'
output_folder = '../../output/lorenz/'

# %% [markdown]
# # Load catalog

# %%
npzfile = np.load(data_folder + 'catalog_small.npz')
traj_norm = npzfile['traj_norm']
stds = npzfile['stds']
tau = npzfile['tau']
dt = npzfile['dt']
Ntrain = npzfile['Ntrain']
h_max = npzfile['h_max']

# %% [markdown]
# # Load RMSE optimization results

# %%
npzfile = np.load(output_folder + 'optim_lorenz_horizon_variable.npz')

hh_ind_done = npzfile['hh_ind_done']
horizon = npzfile['horizon']
transform_optim_zzvar_RMSE = npzfile['transform_optim_zzvar']
k = npzfile['k']

# %% [markdown]
# # CRPS optimization starting from RMSE optimization

# %%
## Define training explanatory variable and forecast horizon
i_h = 3
train_x = traj_norm[::int(tau/dt)][:Ntrain]
hh_ind_crps = hh_ind_done[i_h]
horizon_crps = dt * hh_ind_crps

## Set parameters for optimization
k = 200
nn_algo = 'kd_tree'
loo = True
corr_length_train = 0
regul_coef = [0]
n_epoch = 100
learning_rate_factor_crps = 2e2
Itrain = np.arange(len(train_x))
Ntar = 10**4 # smaller test size for optimization as CRPS computation has a higher computational cost
Itar = np.arange(Ntar)

### Run optimization ###

train_y = (traj_norm[hh_ind_crps::int(tau/dt),2][:Ntrain])[:,np.newaxis]

train_X = apply_transform(train_x, transform_optim_zzvar_RMSE[i_h], Itrain)
        
nn = NearestNeighbors( algorithm = nn_algo , 
                          n_neighbors = k + 1 + 2*corr_length_train ) # leave-one-out procedure + anticipating time-correlated data
nn.fit(train_X)

crps_init = compute_error(train_X[Itar], train_y, Itrain, Itar, k, nn, loo=True, corr_length_train=0, vector_out=False, error_type='CRPS')

learning_rate = learning_rate_factor_crps / crps_init

result = learn_distance(train_x, train_y, transform_optim_zzvar_RMSE[i_h], Itrain, Itar, [], 
                   k = k, nn_algo=nn_algo, error_type='CRPS', n_epoch=n_epoch,
                    learning_rate = learning_rate, regul_coef = regul_coef,
                   loo=True, corr_length_train=corr_length_train,
                     batch_size = Ntar, verbose_batch = True)


transform_optim_crps = result[0][-1].copy()
crps_optim = result[2].copy()
# Out:
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = matrix (general linear transformation)
# Number of analogues = 200
# Learning rate = 26601.291838246227
# Number of Epochs = 100
# Mini-batch size = 10000
# Regularization = [0]
#   0%|          | 0/100 [00:00<?, ?it/s]
# epoch 1/100   |   iter. 1/1 :
# CRPS(batch) = 0.00751843 ;  CRPS(train) = 0.00751843 ;  CRPS(test) = [nan]
# epoch 2/100   |   iter. 1/1 :
# CRPS(batch) = 0.00693950 ;  CRPS(train) = 0.00693950 ;  CRPS(test) = [nan]
# epoch 3/100   |   iter. 1/1 :
# CRPS(batch) = 0.00651957 ;  CRPS(train) = 0.00651957 ;  CRPS(test) = [nan]
# epoch 4/100   |   iter. 1/1 :
# CRPS(batch) = 0.00619344 ;  CRPS(train) = 0.00619344 ;  CRPS(test) = [nan]
# epoch 5/100   |   iter. 1/1 :
# CRPS(batch) = 0.00593058 ;  CRPS(train) = 0.00593058 ;  CRPS(test) = [nan]
# epoch 6/100   |   iter. 1/1 :
# CRPS(batch) = 0.00571670 ;  CRPS(train) = 0.00571670 ;  CRPS(test) = [nan]
# epoch 7/100   |   iter. 1/1 :
# CRPS(batch) = 0.00560993 ;  CRPS(train) = 0.00560993 ;  CRPS(test) = [nan]
# epoch 8/100   |   iter. 1/1 :
# CRPS(batch) = 0.00569505 ;  CRPS(train) = 0.00569505 ;  CRPS(test) = [nan]
# epoch 9/100   |   iter. 1/1 :
# CRPS(batch) = 0.00525186 ;  CRPS(train) = 0.00525186 ;  CRPS(test) = [nan]
# epoch 10/100   |   iter. 1/1 :
# CRPS(batch) = 0.00513194 ;  CRPS(train) = 0.00513194 ;  CRPS(test) = [nan]
# epoch 11/100   |   iter. 1/1 :
# CRPS(batch) = 0.00502598 ;  CRPS(train) = 0.00502598 ;  CRPS(test) = [nan]
# epoch 12/100   |   iter. 1/1 :
# CRPS(batch) = 0.00493154 ;  CRPS(train) = 0.00493154 ;  CRPS(test) = [nan]
# epoch 13/100   |   iter. 1/1 :
# CRPS(batch) = 0.00484669 ;  CRPS(train) = 0.00484669 ;  CRPS(test) = [nan]
# epoch 14/100   |   iter. 1/1 :
# CRPS(batch) = 0.00476994 ;  CRPS(train) = 0.00476994 ;  CRPS(test) = [nan]
# epoch 15/100   |   iter. 1/1 :
# CRPS(batch) = 0.00470011 ;  CRPS(train) = 0.00470011 ;  CRPS(test) = [nan]
# epoch 16/100   |   iter. 1/1 :
# CRPS(batch) = 0.00463623 ;  CRPS(train) = 0.00463623 ;  CRPS(test) = [nan]
# epoch 17/100   |   iter. 1/1 :
# CRPS(batch) = 0.00457751 ;  CRPS(train) = 0.00457751 ;  CRPS(test) = [nan]
# epoch 18/100   |   iter. 1/1 :
# CRPS(batch) = 0.00452330 ;  CRPS(train) = 0.00452330 ;  CRPS(test) = [nan]
# epoch 19/100   |   iter. 1/1 :
# CRPS(batch) = 0.00447307 ;  CRPS(train) = 0.00447307 ;  CRPS(test) = [nan]
# epoch 20/100   |   iter. 1/1 :
# CRPS(batch) = 0.00442634 ;  CRPS(train) = 0.00442634 ;  CRPS(test) = [nan]
# epoch 21/100   |   iter. 1/1 :
# CRPS(batch) = 0.00438274 ;  CRPS(train) = 0.00438274 ;  CRPS(test) = [nan]
# epoch 22/100   |   iter. 1/1 :
# CRPS(batch) = 0.00434194 ;  CRPS(train) = 0.00434194 ;  CRPS(test) = [nan]
# epoch 23/100   |   iter. 1/1 :
# CRPS(batch) = 0.00430364 ;  CRPS(train) = 0.00430364 ;  CRPS(test) = [nan]
# epoch 24/100   |   iter. 1/1 :
# CRPS(batch) = 0.00426762 ;  CRPS(train) = 0.00426762 ;  CRPS(test) = [nan]
# epoch 25/100   |   iter. 1/1 :
# CRPS(batch) = 0.00423364 ;  CRPS(train) = 0.00423364 ;  CRPS(test) = [nan]
# epoch 26/100   |   iter. 1/1 :
# CRPS(batch) = 0.00420154 ;  CRPS(train) = 0.00420154 ;  CRPS(test) = [nan]
# epoch 27/100   |   iter. 1/1 :
# CRPS(batch) = 0.00417115 ;  CRPS(train) = 0.00417115 ;  CRPS(test) = [nan]
# epoch 28/100   |   iter. 1/1 :
# CRPS(batch) = 0.00414233 ;  CRPS(train) = 0.00414233 ;  CRPS(test) = [nan]
# epoch 29/100   |   iter. 1/1 :
# CRPS(batch) = 0.00411495 ;  CRPS(train) = 0.00411495 ;  CRPS(test) = [nan]
# epoch 30/100   |   iter. 1/1 :
# CRPS(batch) = 0.00408890 ;  CRPS(train) = 0.00408890 ;  CRPS(test) = [nan]
# epoch 31/100   |   iter. 1/1 :
# CRPS(batch) = 0.00406407 ;  CRPS(train) = 0.00406407 ;  CRPS(test) = [nan]
# epoch 32/100   |   iter. 1/1 :
# CRPS(batch) = 0.00404039 ;  CRPS(train) = 0.00404039 ;  CRPS(test) = [nan]
# epoch 33/100   |   iter. 1/1 :
# CRPS(batch) = 0.00401775 ;  CRPS(train) = 0.00401775 ;  CRPS(test) = [nan]
# epoch 34/100   |   iter. 1/1 :
# CRPS(batch) = 0.00399609 ;  CRPS(train) = 0.00399609 ;  CRPS(test) = [nan]
# epoch 35/100   |   iter. 1/1 :
# CRPS(batch) = 0.00397533 ;  CRPS(train) = 0.00397533 ;  CRPS(test) = [nan]
# epoch 36/100   |   iter. 1/1 :
# CRPS(batch) = 0.00395541 ;  CRPS(train) = 0.00395541 ;  CRPS(test) = [nan]
# epoch 37/100   |   iter. 1/1 :
# CRPS(batch) = 0.00393626 ;  CRPS(train) = 0.00393626 ;  CRPS(test) = [nan]
# epoch 38/100   |   iter. 1/1 :
# CRPS(batch) = 0.00391781 ;  CRPS(train) = 0.00391781 ;  CRPS(test) = [nan]
# epoch 39/100   |   iter. 1/1 :
# CRPS(batch) = 0.00389997 ;  CRPS(train) = 0.00389997 ;  CRPS(test) = [nan]
# epoch 40/100   |   iter. 1/1 :
# CRPS(batch) = 0.00388253 ;  CRPS(train) = 0.00388253 ;  CRPS(test) = [nan]
# epoch 41/100   |   iter. 1/1 :
# CRPS(batch) = 0.00386502 ;  CRPS(train) = 0.00386502 ;  CRPS(test) = [nan]
# epoch 42/100   |   iter. 1/1 :
# CRPS(batch) = 0.00384724 ;  CRPS(train) = 0.00384724 ;  CRPS(test) = [nan]
# epoch 43/100   |   iter. 1/1 :
# CRPS(batch) = 0.00383080 ;  CRPS(train) = 0.00383080 ;  CRPS(test) = [nan]
# epoch 44/100   |   iter. 1/1 :
# CRPS(batch) = 0.00381540 ;  CRPS(train) = 0.00381540 ;  CRPS(test) = [nan]
# epoch 45/100   |   iter. 1/1 :
# CRPS(batch) = 0.00380077 ;  CRPS(train) = 0.00380077 ;  CRPS(test) = [nan]
# epoch 46/100   |   iter. 1/1 :
# CRPS(batch) = 0.00378678 ;  CRPS(train) = 0.00378678 ;  CRPS(test) = [nan]
# epoch 47/100   |   iter. 1/1 :
# CRPS(batch) = 0.00377332 ;  CRPS(train) = 0.00377332 ;  CRPS(test) = [nan]
# epoch 48/100   |   iter. 1/1 :
# CRPS(batch) = 0.00376031 ;  CRPS(train) = 0.00376031 ;  CRPS(test) = [nan]
# epoch 49/100   |   iter. 1/1 :
# CRPS(batch) = 0.00374770 ;  CRPS(train) = 0.00374770 ;  CRPS(test) = [nan]
# epoch 50/100   |   iter. 1/1 :
# CRPS(batch) = 0.00373546 ;  CRPS(train) = 0.00373546 ;  CRPS(test) = [nan]
# epoch 51/100   |   iter. 1/1 :
# CRPS(batch) = 0.00372358 ;  CRPS(train) = 0.00372358 ;  CRPS(test) = [nan]
# epoch 52/100   |   iter. 1/1 :
# CRPS(batch) = 0.00371203 ;  CRPS(train) = 0.00371203 ;  CRPS(test) = [nan]
# epoch 53/100   |   iter. 1/1 :
# CRPS(batch) = 0.00370081 ;  CRPS(train) = 0.00370081 ;  CRPS(test) = [nan]
# epoch 54/100   |   iter. 1/1 :
# CRPS(batch) = 0.00368990 ;  CRPS(train) = 0.00368990 ;  CRPS(test) = [nan]
# epoch 55/100   |   iter. 1/1 :
# CRPS(batch) = 0.00367926 ;  CRPS(train) = 0.00367926 ;  CRPS(test) = [nan]
# epoch 56/100   |   iter. 1/1 :
# CRPS(batch) = 0.00366886 ;  CRPS(train) = 0.00366886 ;  CRPS(test) = [nan]
# epoch 57/100   |   iter. 1/1 :
# CRPS(batch) = 0.00365866 ;  CRPS(train) = 0.00365866 ;  CRPS(test) = [nan]
# epoch 58/100   |   iter. 1/1 :
# CRPS(batch) = 0.00364860 ;  CRPS(train) = 0.00364860 ;  CRPS(test) = [nan]
# epoch 59/100   |   iter. 1/1 :
# CRPS(batch) = 0.00363856 ;  CRPS(train) = 0.00363856 ;  CRPS(test) = [nan]
# epoch 60/100   |   iter. 1/1 :
# CRPS(batch) = 0.00362827 ;  CRPS(train) = 0.00362827 ;  CRPS(test) = [nan]
# epoch 61/100   |   iter. 1/1 :
# CRPS(batch) = 0.00361751 ;  CRPS(train) = 0.00361751 ;  CRPS(test) = [nan]
# epoch 62/100   |   iter. 1/1 :
# CRPS(batch) = 0.00360708 ;  CRPS(train) = 0.00360708 ;  CRPS(test) = [nan]
# epoch 63/100   |   iter. 1/1 :
# CRPS(batch) = 0.00359734 ;  CRPS(train) = 0.00359734 ;  CRPS(test) = [nan]
# epoch 64/100   |   iter. 1/1 :
# CRPS(batch) = 0.00358792 ;  CRPS(train) = 0.00358792 ;  CRPS(test) = [nan]
# epoch 65/100   |   iter. 1/1 :
# CRPS(batch) = 0.00357867 ;  CRPS(train) = 0.00357867 ;  CRPS(test) = [nan]
# epoch 66/100   |   iter. 1/1 :
# CRPS(batch) = 0.00356959 ;  CRPS(train) = 0.00356959 ;  CRPS(test) = [nan]
# epoch 67/100   |   iter. 1/1 :
# CRPS(batch) = 0.00356082 ;  CRPS(train) = 0.00356082 ;  CRPS(test) = [nan]
# epoch 68/100   |   iter. 1/1 :
# CRPS(batch) = 0.00355245 ;  CRPS(train) = 0.00355245 ;  CRPS(test) = [nan]
# epoch 69/100   |   iter. 1/1 :
# CRPS(batch) = 0.00354442 ;  CRPS(train) = 0.00354442 ;  CRPS(test) = [nan]
# epoch 70/100   |   iter. 1/1 :
# CRPS(batch) = 0.00353669 ;  CRPS(train) = 0.00353669 ;  CRPS(test) = [nan]
# epoch 71/100   |   iter. 1/1 :
# CRPS(batch) = 0.00352923 ;  CRPS(train) = 0.00352923 ;  CRPS(test) = [nan]
# epoch 72/100   |   iter. 1/1 :
# CRPS(batch) = 0.00352210 ;  CRPS(train) = 0.00352210 ;  CRPS(test) = [nan]
# epoch 73/100   |   iter. 1/1 :
# CRPS(batch) = 0.00351582 ;  CRPS(train) = 0.00351582 ;  CRPS(test) = [nan]
# epoch 74/100   |   iter. 1/1 :
# CRPS(batch) = 0.00351379 ;  CRPS(train) = 0.00351379 ;  CRPS(test) = [nan]
# epoch 75/100   |   iter. 1/1 :
# CRPS(batch) = 0.00353661 ;  CRPS(train) = 0.00353661 ;  CRPS(test) = [nan]
# epoch 76/100   |   iter. 1/1 :
# CRPS(batch) = 0.00361662 ;  CRPS(train) = 0.00361662 ;  CRPS(test) = [nan]
# epoch 77/100   |   iter. 1/1 :
# CRPS(batch) = 0.00353879 ;  CRPS(train) = 0.00353879 ;  CRPS(test) = [nan]
# epoch 78/100   |   iter. 1/1 :
# CRPS(batch) = 0.00350872 ;  CRPS(train) = 0.00350872 ;  CRPS(test) = [nan]
# epoch 79/100   |   iter. 1/1 :
# CRPS(batch) = 0.00349830 ;  CRPS(train) = 0.00349830 ;  CRPS(test) = [nan]
# epoch 80/100   |   iter. 1/1 :
# CRPS(batch) = 0.00349045 ;  CRPS(train) = 0.00349045 ;  CRPS(test) = [nan]
# epoch 81/100   |   iter. 1/1 :
# CRPS(batch) = 0.00348301 ;  CRPS(train) = 0.00348301 ;  CRPS(test) = [nan]
# epoch 82/100   |   iter. 1/1 :
# CRPS(batch) = 0.00347494 ;  CRPS(train) = 0.00347494 ;  CRPS(test) = [nan]
# epoch 83/100   |   iter. 1/1 :
# CRPS(batch) = 0.00346555 ;  CRPS(train) = 0.00346555 ;  CRPS(test) = [nan]
# epoch 84/100   |   iter. 1/1 :
# CRPS(batch) = 0.00345739 ;  CRPS(train) = 0.00345739 ;  CRPS(test) = [nan]
# epoch 85/100   |   iter. 1/1 :
# CRPS(batch) = 0.00345005 ;  CRPS(train) = 0.00345005 ;  CRPS(test) = [nan]
# epoch 86/100   |   iter. 1/1 :
# CRPS(batch) = 0.00344319 ;  CRPS(train) = 0.00344319 ;  CRPS(test) = [nan]
# epoch 87/100   |   iter. 1/1 :
# CRPS(batch) = 0.00343703 ;  CRPS(train) = 0.00343703 ;  CRPS(test) = [nan]
# epoch 88/100   |   iter. 1/1 :
# CRPS(batch) = 0.00343145 ;  CRPS(train) = 0.00343145 ;  CRPS(test) = [nan]
# epoch 89/100   |   iter. 1/1 :
# CRPS(batch) = 0.00342622 ;  CRPS(train) = 0.00342622 ;  CRPS(test) = [nan]
# epoch 90/100   |   iter. 1/1 :
# CRPS(batch) = 0.00342122 ;  CRPS(train) = 0.00342122 ;  CRPS(test) = [nan]
# epoch 91/100   |   iter. 1/1 :
# CRPS(batch) = 0.00341645 ;  CRPS(train) = 0.00341645 ;  CRPS(test) = [nan]
# epoch 92/100   |   iter. 1/1 :
# CRPS(batch) = 0.00341219 ;  CRPS(train) = 0.00341219 ;  CRPS(test) = [nan]
# epoch 93/100   |   iter. 1/1 :
# CRPS(batch) = 0.00341050 ;  CRPS(train) = 0.00341050 ;  CRPS(test) = [nan]
# epoch 94/100   |   iter. 1/1 :
# CRPS(batch) = 0.00342519 ;  CRPS(train) = 0.00342519 ;  CRPS(test) = [nan]
# epoch 95/100   |   iter. 1/1 :
# CRPS(batch) = 0.00350529 ;  CRPS(train) = 0.00350529 ;  CRPS(test) = [nan]
# epoch 96/100   |   iter. 1/1 :
# CRPS(batch) = 0.00347241 ;  CRPS(train) = 0.00347241 ;  CRPS(test) = [nan]
# epoch 97/100   |   iter. 1/1 :
# CRPS(batch) = 0.00341402 ;  CRPS(train) = 0.00341402 ;  CRPS(test) = [nan]
# epoch 98/100   |   iter. 1/1 :
# CRPS(batch) = 0.00340716 ;  CRPS(train) = 0.00340716 ;  CRPS(test) = [nan]
# epoch 99/100   |   iter. 1/1 :
# CRPS(batch) = 0.00340092 ;  CRPS(train) = 0.00340092 ;  CRPS(test) = [nan]
# epoch 100/100   |   iter. 1/1 :
# CRPS(batch) = 0.00339390 ;  CRPS(train) = 0.00339390 ;  CRPS(test) = [nan]
# epoch. 100/100 :
# CRPS(train) = 0.00338555 ;  CRPS(test) = [nan]

# %% [markdown]
# # Save

# %%
np.savez(output_folder + 'optim_lorenz_crps.npz',
        transform_optim_crps = transform_optim_crps,
        transform_optim_rmse = transform_optim_zzvar_RMSE[i_h],
        crps_optim = crps_optim,
         horizon = horizon_crps,
         hh_ind = hh_ind_crps,
         learning_rate_factor_crps = learning_rate_factor_crps,
        )
