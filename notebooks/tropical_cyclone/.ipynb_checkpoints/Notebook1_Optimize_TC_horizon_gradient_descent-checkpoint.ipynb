# %% [markdown]
# # Optimize distance : forecasting of tropical cylone data as a function of horizon
#
# This notebook accompanies the following publication:
# Paul Platzer, Arthur Avenas, Bertrand Chapron, Lucas Drumetz, Alexis Mouche, Léo Vinour. Distance Learning for Analog Methods. 2024. [⟨hal-04841334⟩](https://hal.science/hal-04841334)
#
# It is used to run optimization algorithms for numerical experiments with IBTrACS tropical cyclone data, varying the forecast horizon.

# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt
import matplotlib
from tqdm.notebook import tqdm
from sklearn.neighbors import NearestNeighbors
import os
os.environ["OMP_NUM_THREADS"] = "16"
os.environ["OPENBLAS_NUM_THREADS"] = "16"
os.environ["MKL_NUM_THREADS"] = "16"
os.environ["NUMEXPR_NUM_THREADS"] = "16"
import sys
sys.path.append('../../functions/.')
from analogs import apply_transform, find_analogues, compute_weights, compute_diffs, compute_mae_mad, compute_error
from distance_learning import compute_gradient_MSE, compute_gradient_CRPS, compute_regularization, learn_distance
from TC_utils import M, Rmax_from_M, correct_vmx_ibt, Rmxa23

# %%
data_folder = '../../data/tropical_cyclone/'
output_folder = '../../output/tropical_cyclone/'

# %%
matplotlib.rcParams.update({'font.size': 14})
cols = ['#377eb8', '#ff7f00', '#4daf4a',
                  '#f781bf', '#a65628', '#984ea3',
                  '#999999', '#e41a1c', '#dede00']

# %% [markdown]
# # Parameters for loading IBTrACS dataset

# %%
files = os.listdir(data_folder)

# Input variables
var_names = ['Vmax', 'Rmax_IBT', 'R34', 'fcor', 'u_trans', 'v_trans']

# Output variable to forecast: derivative of Vmax
var_y = ['Vmax']
dydt = True
ind_var_y = []
for name_tmp in var_y:
    ind_var_y.append(np.argwhere(np.array(var_names)==name_tmp)[0][0])

# Utils to compute Rmax estimate from Avenas et al. (2023)
var_A23 = ['fcor', 'Vmax', 'R34', ]
ind_A23 = []
for name_tmp in var_A23:
    ind_A23.append(np.argwhere(np.array(var_names)==name_tmp)[0][0])

# Add names of auxilliary variables (Rmax_A23 and time-derivatives)
var_names_all = var_names.copy()
var_names_all.append('Rmax_A23')
for name in var_names_all.copy():
    var_names_all.append('d'+name+'/dt')

# Add name of time since the threshold of 18m/s is crossed for Vmax
var_names_all.append('t_18')

# %% [markdown]
# # Optimization loop on forecast horizon

# %%
## Set parameters for optimization
transform_diagonal = np.ones(len(var_names_all))
k = 200
regul_coef = [0]
regul_type = 'l1'
# n_epoch = 3
n_iter = 20
# n_epoch = 1
batch_size = 4000
corr_length_train = 24
Nperm = 10
learning_rate_factor = 1*1e1
nn_algo = 'auto'
compute_error_train = False
n_jobs=-1

# Initialize lists to store results
A = [] # transform matrix (diagonal)
E_batch = [] # error on train set (CRPS)
E_train = [] # error on train set (CRPS)
E_test = [] # error on test set
hh = [] # horizon index

# for h in tqdm(np.arange(4,40+4,4)[:1]):
for h in tqdm(np.arange(4,40+4,4)):
    print('')
    print('Horizon = '+str(h*3)+'hours')
    print('')
    
    IBT = np.array(pandas.read_csv(data_folder + files[0], usecols = var_names))
    IBT = np.concatenate( [ IBT , 
             Rmxa23(IBT[:,ind_A23[0]] , IBT[:,ind_A23[1]] , IBT[:,ind_A23[2]]).reshape(-1,1) ,
                          ],  axis=1)
    IBT = np.concatenate( ( IBT[1:] , IBT[1:] - IBT[:-1] ) , axis=1 )
    IBT = np.concatenate( [ IBT ,
               3*np.arange(len(IBT)).reshape(-1,1) ],  axis=1)
    train_x = IBT[0:-h,:]
    train_y = IBT[h:,ind_var_y] - IBT[0:-h,ind_var_y] 
    ID = np.array([0]*len(IBT[0:-h,:]))
    

    for i in np.arange(1, len(files)):
        IBT = np.array(pandas.read_csv(data_folder + files[i], usecols = var_names))
        IBT = np.concatenate( [ IBT , 
                 Rmxa23(IBT[:,ind_A23[0]] , IBT[:,ind_A23[1]] , IBT[:,ind_A23[2]]).reshape(-1,1) ,
                              ],  axis=1)
        IBT = np.concatenate( ( IBT[1:] , IBT[1:] - IBT[:-1] ) , axis=1 )
        IBT = np.concatenate( [ IBT ,
               3*np.arange(len(IBT)).reshape(-1,1) ],  axis=1)
        train_x = np.concatenate([train_x, IBT[0:-h,:]])
        train_y = np.concatenate([train_y, IBT[h:,ind_var_y] - IBT[0:-h,ind_var_y]])
        ID = np.concatenate([ID, np.array([i]*len(IBT[0:-h,:]))])

    # center and reduce the 6 columns
    mean_IBTrACS = np.mean(train_x, axis=0)
    std_IBTrACS = np.std(train_x, axis=0)
    mean_y = np.mean(train_y, axis=0)
    std_y = np.std(train_y, axis=0)
    for j in range(train_x.shape[1]):
        train_x[:,j] = (train_x[:,j] - mean_IBTrACS[j]) / std_IBTrACS[j]
    for j in range(train_y.shape[1]):
        train_y[:,j] = (train_y[:,j] - mean_y[j]) / std_y[j]
        
    print('Dataset size = ' + str(len(train_x)))
    print('')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Horizon = 12hours
#
# Dataset size = 34612
#
#
# Horizon = 24hours
#
# Dataset size = 30420
#
#
# Horizon = 36hours
#
# Dataset size = 26258
#
#
# Horizon = 48hours
#
# Dataset size = 22502
#
#
# Horizon = 60hours
#
# Dataset size = 19174
#
#
# Horizon = 72hours
#
# Dataset size = 16196
#
#
# Horizon = 84hours
#
# Dataset size = 13612
#
#
# Horizon = 96hours
#
# Dataset size = 11388
#
#
# Horizon = 108hours
#
# Dataset size = 9489
#
#
# Horizon = 120hours
#
# Dataset size = 7892

# %%
## Set parameters for optimization
transform_diagonal = np.ones(len(var_names_all))
k = 200
regul_coef = [0]
regul_type = 'l1'
# n_epoch = 3
n_iter = 20
# n_epoch = 1
batch_size = 4000
corr_length_train = 24
Nperm = 10
learning_rate_factor = 1*1e1
nn_algo = 'auto'
compute_error_train = False
n_jobs=-1

# Initialize lists to store results
A = [] # transform matrix (diagonal)
E_batch = [] # error on train set (CRPS)
E_train = [] # error on train set (CRPS)
E_test = [] # error on test set
hh = [] # horizon index

for h in tqdm(np.arange(4,40+4,4)):
    print('')
    print('Horizon = '+str(h*3)+'hours')
    print('')
    
    IBT = np.array(pandas.read_csv(data_folder + files[0], usecols = var_names))
    IBT = np.concatenate( [ IBT , 
             Rmxa23(IBT[:,ind_A23[0]] , IBT[:,ind_A23[1]] , IBT[:,ind_A23[2]]).reshape(-1,1) ,
                          ],  axis=1)
    IBT = np.concatenate( ( IBT[1:] , IBT[1:] - IBT[:-1] ) , axis=1 )
    IBT = np.concatenate( [ IBT ,
               3*np.arange(len(IBT)).reshape(-1,1) ],  axis=1)
    train_x = IBT[0:-h,:]
    train_y = IBT[h:,ind_var_y] - IBT[0:-h,ind_var_y] 
    ID = np.array([0]*len(IBT[0:-h,:]))
    

    for i in np.arange(1, len(files)):
        IBT = np.array(pandas.read_csv(data_folder + files[i], usecols = var_names))
        IBT = np.concatenate( [ IBT , 
                 Rmxa23(IBT[:,ind_A23[0]] , IBT[:,ind_A23[1]] , IBT[:,ind_A23[2]]).reshape(-1,1) ,
                              ],  axis=1)
        IBT = np.concatenate( ( IBT[1:] , IBT[1:] - IBT[:-1] ) , axis=1 )
        IBT = np.concatenate( [ IBT ,
               3*np.arange(len(IBT)).reshape(-1,1) ],  axis=1)
        train_x = np.concatenate([train_x, IBT[0:-h,:]])
        train_y = np.concatenate([train_y, IBT[h:,ind_var_y] - IBT[0:-h,ind_var_y]])
        ID = np.concatenate([ID, np.array([i]*len(IBT[0:-h,:]))])

    # center and reduce the 6 columns
    mean_IBTrACS = np.mean(train_x, axis=0)
    std_IBTrACS = np.std(train_x, axis=0)
    mean_y = np.mean(train_y, axis=0)
    std_y = np.std(train_y, axis=0)
    for j in range(train_x.shape[1]):
        train_x[:,j] = (train_x[:,j] - mean_IBTrACS[j]) / std_IBTrACS[j]
    for j in range(train_y.shape[1]):
        train_y[:,j] = (train_y[:,j] - mean_y[j]) / std_y[j]
        
        
    A_grad = []
    E_grad_batch = []
    E_grad_train = []
    E_grad_test = []
    random_state_number = []
    
    for i_perm in range(Nperm):
        # Generate random permutation (reproducible)
        random_state_number.append(1312 + i_perm)
        rs = np.random.RandomState(random_state_number[-1])
        perm = rs.permutation(len(files))
        Itest = np.argwhere(np.isin(ID, perm[:len(files)//3]))[:,0]
        Itrain = np.argwhere(np.isin(ID, perm[len(files)//3:]))[:,0]

        train_X = apply_transform(train_x, transform_diagonal, Itrain)
        
        nn = NearestNeighbors( algorithm = nn_algo , 
                                  n_neighbors = k + 1 + 2*corr_length_train ) # leave-one-out procedure + anticipating time-correlated data
        nn.fit(train_X)
        
        crps_init = compute_error(train_X, train_y, Itrain, Itrain, k, nn,
                                  loo=True, corr_length_train=corr_length_train, vector_out=False, error_type='CRPS')
        learning_rate_crps = learning_rate_factor/crps_init

        result_crps = learn_distance(train_x, train_y, transform_diagonal, Itrain, Itrain, Itest, 
                   k = k, nn_algo='auto', error_type='CRPS', 
                                     # n_epoch=n_epoch,
                                     n_iter=n_iter,
                    learning_rate = learning_rate_crps, regul_coef = regul_coef, regul_type = regul_type,
                   loo=True, corr_length_train=corr_length_train,
                     batch_size = batch_size, compute_error_train = compute_error_train,
                         n_jobs=n_jobs, verbose_batch = True)
        
        A_grad.append( result_crps[0].copy() )
        E_grad_batch.append( result_crps[1].copy() )
        E_grad_train.append( result_crps[2].copy() )
        E_grad_test.append( result_crps[3].copy() )

    
    A.append( np.array(A_grad).copy() )
    E_batch.append( np.array(E_grad_batch).copy() )
    E_train.append( np.array(E_grad_train).copy() )
    E_test.append( np.array(E_grad_test).copy() )
    hh.append(h)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Horizon = 12hours
#
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 25.839652112901618
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.84E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.74E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.76E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.77E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.63E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.73E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.74E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.69E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.50E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.50E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.49E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.49E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.48E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.48E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.48E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.48E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.43427855668532
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.86E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.88E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.63E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.82E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.70E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.63E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.75E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.73E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.69E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.69E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.48E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.43E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.48E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.48E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.49E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.086776951176006
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.86E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.70E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.64E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.62E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.63E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.67E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.63E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.63E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.64E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.48E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 25.81356514574364
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.95E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.84E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.77E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.50E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.49E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.66E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.48E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.64E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.46E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.45E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.45E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.45E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.44E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.44E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.54E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.44E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.44E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.43E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.43E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.075027268929837
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.78E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.73E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.79E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.64E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.61E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.63E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.54E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.69E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.64E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.54E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.51E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.51E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.50E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.50E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.50E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.50E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.49E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.49E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.49E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.49E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.087905817514283
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.90E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.85E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.77E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.76E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.73E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.67E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.69E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.64E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.62E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.54E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.61E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.49E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.66E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.54E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 25.82288860530089
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.92E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.73E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.82E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.72E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.62E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.70E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.66E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.73E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.67E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.50E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.49E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.48E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.73E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.46E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.64E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.46E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.66E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.45E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.45E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.45E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.44E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.44E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.44E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.67E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.44E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.44E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 25.99624960865332
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.81E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.89E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.75E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.69E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.70E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.69E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.63E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.61E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.63E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.70E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.66E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.48E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.66E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.51E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.64E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.47E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.51E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.51E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.51E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 25.904011183322208
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.81E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.75E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.76E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.64E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.61E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.69E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.72E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.66E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.51E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.50E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.49E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.64E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.48E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.48E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.48E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.63E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.46E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.46E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.46E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.23980743662614
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.83E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.84E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.73E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.64E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.64E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.63E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.62E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.61E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.49E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.154109230335155
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.86E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.82E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.74E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.70E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.70E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.63E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.67E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.62E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.49E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.07308030442596
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.83E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.74E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.62E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.48E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.686227958765684
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.83E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.99E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.93E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.88E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.84E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.81E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.54E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.79E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.76E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.75E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.49E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.74E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.73E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.47E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.46E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.34E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.46E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.49E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.46E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.15706378482199
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.83E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.82E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.79E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.76E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.70E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.66E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.64E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.62E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.67E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.61E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.44E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.49E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.26906711041205
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.81E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.82E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.78E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.76E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.65E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.54E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.63E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.61E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.61E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.52E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.47E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.54E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.42E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.26266993064951
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.85E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.85E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.67E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.79E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.74E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.73E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.67E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.49E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.64E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.63E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.62E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.61E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.54E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.54E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.50E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.21282153279394
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.79E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.83E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.72E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.74E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.73E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.69E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.72E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.63E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.61E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.59E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.58E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.57E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.69E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.48E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.55E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.55E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.53E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.54E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.53E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 25.603180599861574
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.94E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.66E-01
# epoch 1/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.82E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.60E-01
# epoch 1/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.82E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.56E-01
# epoch 1/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.76E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.52E-01
# epoch 1/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.72E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.50E-01
# epoch 1/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.47E-01
# epoch 2/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.67E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.46E-01
# epoch 2/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.64E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.45E-01
# epoch 2/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.68E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.44E-01
# epoch 2/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.43E-01
# epoch 2/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.66E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.43E-01
# epoch 2/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.42E-01
# epoch 3/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.67E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.42E-01
# epoch 3/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.42E-01
# epoch 3/4   |   iter. 3/6 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.41E-01
# epoch 3/4   |   iter. 4/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.41E-01
# epoch 3/4   |   iter. 5/6 :
# CRPS(mini-batch) = 3.56E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.41E-01
# epoch 3/4   |   iter. 6/6 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.41E-01
# epoch 4/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.57E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.41E-01
# epoch 4/4   |   iter. 2/6 :
# CRPS(mini-batch) = 3.59E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.41E-01
# epoch. 4/4 :
# CRPS(train) = NAN ;  CRPS(test) = 3.41E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 26.440765332333164
# Number of Epochs = 4
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/4 [00:00<?, ?it/s]
# epoch 1/4   |   iter. 1/6 :
# CRPS(mini-batch) = 3.84E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.87E-01
# ...
# CRPS(train) = NAN ;  CRPS(test) = 4.10E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 23.810333324564883
# Number of Epochs = 15
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/15 [00:00<?, ?it/s]
# epoch 1/15   |   iter. 1/2 :
# CRPS(mini-batch) = 4.22E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.29E-01
# epoch 1/15   |   iter. 2/2 :
# CRPS(mini-batch) = 4.03E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.15E-01
# epoch 2/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.97E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.05E-01
# epoch 2/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.95E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.97E-01
# epoch 3/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.84E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.92E-01
# epoch 3/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.93E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.88E-01
# epoch 4/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.76E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.84E-01
# epoch 4/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.94E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.81E-01
# epoch 5/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.79E-01
# epoch 5/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.84E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 6/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.77E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.76E-01
# epoch 6/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.75E-01
# epoch 7/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.77E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.75E-01
# epoch 7/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.69E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.74E-01
# epoch 8/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.71E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.73E-01
# epoch 8/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.83E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 9/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.76E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 9/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch 10/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.73E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.71E-01
# epoch 10/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.74E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.70E-01
# epoch. 10/15 :
# CRPS(train) = NAN ;  CRPS(test) = 3.70E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 24.166272006177355
# Number of Epochs = 16
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/16 [00:00<?, ?it/s]
# epoch 1/16   |   iter. 1/2 :
# CRPS(mini-batch) = 4.13E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.37E-01
# epoch 1/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.98E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.25E-01
# epoch 2/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.90E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.17E-01
# epoch 2/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.70E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.13E-01
# epoch 3/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.11E-01
# epoch 3/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.08E-01
# epoch 4/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.06E-01
# epoch 4/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.51E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.04E-01
# epoch 5/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.66E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.02E-01
# epoch 5/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.01E-01
# epoch 6/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.01E-01
# epoch 6/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.69E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.01E-01
# epoch 7/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.61E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.00E-01
# epoch 7/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.00E-01
# epoch 8/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.01E-01
# epoch 8/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.69E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.01E-01
# epoch 9/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.01E-01
# epoch 9/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.01E-01
# epoch 10/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.60E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.01E-01
# epoch 10/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.58E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.00E-01
# epoch. 10/16 :
# CRPS(train) = NAN ;  CRPS(test) = 4.00E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 23.0693064571555
# Number of Epochs = 16
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/16 [00:00<?, ?it/s]
# epoch 1/16   |   iter. 1/2 :
# CRPS(mini-batch) = 4.32E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.17E-01
# epoch 1/16   |   iter. 2/2 :
# CRPS(mini-batch) = 4.25E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.03E-01
# epoch 2/16   |   iter. 1/2 :
# CRPS(mini-batch) = 4.07E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.94E-01
# epoch 2/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.97E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.88E-01
# epoch 3/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.95E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.84E-01
# epoch 3/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.84E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.81E-01
# epoch 4/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.84E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.79E-01
# epoch 4/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.94E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 5/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.86E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 5/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.71E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 6/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.81E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 6/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.87E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 7/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.81E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 7/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.78E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 8/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.78E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 8/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.87E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 9/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 9/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 10/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.83E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 10/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.65E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch. 10/16 :
# CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 22.897718841706634
# Number of Epochs = 16
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/16 [00:00<?, ?it/s]
# epoch 1/16   |   iter. 1/2 :
# CRPS(mini-batch) = 4.37E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.14E-01
# epoch 1/16   |   iter. 2/2 :
# CRPS(mini-batch) = 4.15E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.00E-01
# epoch 2/16   |   iter. 1/2 :
# CRPS(mini-batch) = 4.09E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.90E-01
# epoch 2/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.84E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.83E-01
# epoch 3/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.92E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 3/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.81E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.75E-01
# epoch 4/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.85E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.72E-01
# epoch 4/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.74E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.70E-01
# epoch 5/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.81E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.70E-01
# epoch 5/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.81E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.69E-01
# epoch 6/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.69E-01
# epoch 6/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.77E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 7/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 7/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.91E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 8/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.68E-01
# epoch 8/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.75E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# epoch 9/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.83E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# epoch 9/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.62E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# epoch 10/16   |   iter. 1/2 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# epoch 10/16   |   iter. 2/2 :
# CRPS(mini-batch) = 3.71E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# epoch. 10/16 :
# CRPS(train) = NAN ;  CRPS(test) = 3.67E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 23.247283406833155
# Number of Epochs = 17
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/17 [00:00<?, ?it/s]
# epoch 1/17   |   iter. 1/2 :
# CRPS(mini-batch) = 4.30E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.33E-01
# epoch 1/17   |   iter. 2/2 :
# CRPS(mini-batch) = 4.19E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.16E-01
# epoch 2/17   |   iter. 1/2 :
# CRPS(mini-batch) = 4.02E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.03E-01
# epoch 2/17   |   iter. 2/2 :
# CRPS(mini-batch) = 4.15E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.94E-01
# epoch 3/17   |   iter. 1/2 :
# CRPS(mini-batch) = 3.92E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.89E-01
# epoch 3/17   |   iter. 2/2 :
# CRPS(mini-batch) = 3.97E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.86E-01
# epoch 4/17   |   iter. 1/2 :
# CRPS(mini-batch) = 3.90E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.83E-01
# epoch 4/17   |   iter. 2/2 :
# CRPS(mini-batch) = 3.81E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.81E-01
# epoch 5/17   |   iter. 1/2 :
# CRPS(mini-batch) = 3.87E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.80E-01
# epoch 5/17   |   iter. 2/2 :
# CRPS(mini-batch) = 3.77E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.79E-01
# epoch 6/17   |   iter. 1/2 :
# CRPS(mini-batch) = 3.84E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.79E-01
# epoch 6/17   |   iter. 2/2 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 7/17   |   iter. 1/2 :
# CRPS(mini-batch) = 3.80E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.79E-01
# epoch 7/17   |   iter. 2/2 :
# CRPS(mini-batch) = 3.85E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.78E-01
# epoch 8/17   |   iter. 1/2 :
# CRPS(mini-batch) = 3.82E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 8/17   |   iter. 2/2 :
# CRPS(mini-batch) = 3.71E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.77E-01
# epoch 9/17   |   iter. 1/2 :
# CRPS(mini-batch) = 3.78E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.76E-01
# epoch 9/17   |   iter. 2/2 :
# CRPS(mini-batch) = 3.86E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.76E-01
# epoch 10/17   |   iter. 1/2 :
# CRPS(mini-batch) = 3.78E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.76E-01
# epoch 10/17   |   iter. 2/2 :
# CRPS(mini-batch) = 3.86E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.76E-01
# epoch. 10/17 :
# CRPS(train) = NAN ;  CRPS(test) = 3.75E-01
# (20, 15)
# Starting distance-learning algorithm with the following parameters:
# Error type = CRPS
# Transformation type = diagonal matrix (weighting of coordinates)
# Number of analogues = 200
# Catalogue and target sets are equal (leave-one-out procedure & leaving time-correlated analogues below 24 time-increments).
# Learning rate = 23.924492319930156
# Number of Epochs = 15
# Mini-batch size = 4000
# Regularization = [0]
# Errors computed = mini-batch, test.
# Errors not computed = train ,
#   0%|          | 0/15 [00:00<?, ?it/s]
# epoch 1/15   |   iter. 1/2 :
# CRPS(mini-batch) = 4.17E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.29E-01
# epoch 1/15   |   iter. 2/2 :
# CRPS(mini-batch) = 4.10E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.17E-01
# epoch 2/15   |   iter. 1/2 :
# CRPS(mini-batch) = 4.00E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.10E-01
# epoch 2/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.81E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.05E-01
# epoch 3/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.90E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 4.02E-01
# epoch 3/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.71E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.99E-01
# epoch 4/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.79E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.98E-01
# epoch 4/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.85E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.96E-01
# epoch 5/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.78E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.95E-01
# epoch 5/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.79E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.95E-01
# epoch 6/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.77E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.95E-01
# epoch 6/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.72E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.94E-01
# epoch 7/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.72E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.94E-01
# epoch 7/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.85E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.94E-01
# epoch 8/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.74E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.93E-01
# epoch 8/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.77E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.93E-01
# epoch 9/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.69E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.93E-01
# epoch 9/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.92E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.92E-01
# epoch 10/15   |   iter. 1/2 :
# CRPS(mini-batch) = 3.73E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.94E-01
# epoch 10/15   |   iter. 2/2 :
# CRPS(mini-batch) = 3.79E-01 ;  CRPS(train) = NAN ;  CRPS(test) = 3.93E-01
# epoch. 10/15 :
# CRPS(train) = NAN ;  CRPS(test) = 3.93E-01
# (20, 15)

# %%
# Save
np.savez(output_folder + 'optim_TC_horizon_gradient-descent.npz',
        var_y = np.array(var_y),
        var_names_all = np.array(var_names_all),
        A = np.array(A),
         E_batch = np.array(E_batch),
        E_train = np.array(E_train),
        E_test = np.array(E_test),
        hh = np.array(hh),
        k = k,
         n_iter = n_iter,
        batch_size = batch_size,
         regul_coef = regul_coef,
         regul_type = regul_type,
         nn_algo = nn_algo,
        corr_length_train = corr_length_train,
        learning_rate_factor = learning_rate_factor,
         random_state_number = np.array(random_state_number)
        )
