# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
folder_nhc = "/home/pplatzer/Documents/pro/postdoc/DATA/TC_NHC/"
file_nhc = "1970-present_OFCL_v_BCD5_ind_ATL_TI_errors_noTDs.txt"

# %%
pd.read_csv(folder_nhc+file_nhc, skipinitialspace=True, sep=' ',
            skiprows=10, header=0, na_values="-9999.0")
# Out:
#                  Date/Time     STMID  F012  F024  F036  F048  F060  F072  \
# 0      20-05-1970/00:00:00  AL011970  0.00  0.00   0.0   0.0   0.0   0.0
# 1      20-05-1970/06:00:00  AL011970  0.00  0.00   0.0   0.0   0.0   0.0
# 2      20-05-1970/12:00:00  AL011970  0.00  0.00   0.0   0.0   0.0   0.0
# 3      20-05-1970/18:00:00  AL011970  1.00  1.00   0.0   0.0   0.0   0.0
# 4      21-05-1970/00:00:00  AL011970  0.33  0.33   0.0   0.0   0.0   0.0
# ...                    ...       ...   ...   ...   ...   ...   ...   ...
# 12754  27-10-2023/18:00:00  AL202023  0.33  0.33   0.0   0.0   0.0   0.0
# 12755  28-10-2023/00:00:00  AL202023  0.33  0.00   0.0   0.0   0.0   0.0
# 12756  28-10-2023/06:00:00  AL202023  0.33  0.00   0.0   0.0   0.0   0.0
# 12757  28-10-2023/12:00:00  AL202023  0.00  0.00   0.0   0.0   0.0   0.0
# 12758  28-10-2023/18:00:00  AL202023  0.00  0.00   0.0   0.0   0.0   0.0
#
#        F096  F120  ...  012hI02  024hI02  036hI02  048hI02  060hI02  072hI02  \
# ...
